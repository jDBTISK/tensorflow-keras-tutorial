# %%
from icrawler.builtin import GoogleImageCrawler

crawler = GoogleImageCrawler(storage={"root_dir": "img/baseball"})
crawler.crawl(keyword="baseball", max_num=1000)
# Out:
# 2018-07-25 21:07:12,605 - INFO - icrawler.crawler - start crawling...
# 2018-07-25 21:07:12,606 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2018-07-25 21:07:12,608 - INFO - icrawler.crawler - starting 1 parser threads...
# 2018-07-25 21:07:12,611 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2018-07-25 21:07:13,391 - INFO - parser - parsing result page https://www.google.com/search?q=baseball&ijn=0&start=0&tbs=&tbm=isch
# 2018-07-25 21:07:13,733 - INFO - downloader - image #1	https://usathss.files.wordpress.com/2017/06/baseball_graphic1.jpg?w=1000&h=600&crop=1
# 2018-07-25 21:07:13,884 - INFO - downloader - image #2	http://i2.wp.com/www.dailycal.org/assets/uploads/2018/04/baseball_zichenzhao_file-900x580.jpg
# 2018-07-25 21:07:15,124 - INFO - downloader - image #3	https://upload.wikimedia.org/wikipedia/en/1/1e/Baseball_%28crop%29.jpg
# ...
