# %%
from icrawler.builtin import GoogleImageCrawler

crawler = GoogleImageCrawler(storage={"root_dir": "img/soccer"})
crawler.crawl(keyword="soccer", max_num=1000)
# Out:
# 2018-07-25 21:38:27,865 - INFO - icrawler.crawler - start crawling...
# 2018-07-25 21:38:27,866 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2018-07-25 21:38:27,869 - INFO - icrawler.crawler - starting 1 parser threads...
# 2018-07-25 21:38:27,870 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2018-07-25 21:38:28,336 - INFO - parser - parsing result page https://www.google.com/search?q=soccer&ijn=0&start=0&tbs=&tbm=isch
# 2018-07-25 21:38:29,274 - INFO - downloader - image #1	https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/Football_iu_1996.jpg/1200px-Football_iu_1996.jpg
# 2018-07-25 21:38:32,355 - INFO - downloader - image #2	https://www.soccer.com/wcm/connect/5f0b0e03-9c96-40f6-a0bc-0c830df30e31/WC-2up.jpg?MOD=AJPERES&CACHEID=ROOTWORKSPACE-5f0b0e03-9c96-40f6-a0bc-0c830df30e31-miP3kDj
# 2018-07-25 21:38:32,742 - INFO - downloader - image #3	https://www.kinet.co.jp/wp-content/uploads/soccer-ball-ss-img.jpg
# ...
